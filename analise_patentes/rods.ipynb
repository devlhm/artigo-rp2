# %%
import pandas as pd

# %%
file_path = "./datasets/data.jsonl.gz"

df = pd.read_json(file_path, lines=True)

# %%
display(len(df))
print(df.columns)
# Out:
# 50000
# Index(['lens_id', 'jurisdiction', 'doc_number', 'kind', 'date_published',
#        'doc_key', 'docdb_id', 'lang', 'biblio', 'families', 'legal_status',
#        'publication_type', 'abstract'],
#       dtype='object')

# %%
df[df['biblio'].apply(lambda x: 'references_cited' in x if isinstance(x, dict) else False)]
# Out:
# Empty DataFrame
# Columns: [lens_id, jurisdiction, doc_number, kind, date_published, doc_key, docdb_id, lang, biblio, families, legal_status, publication_type, abstract]
# Index: []
