# %%
import pandas as pd
import os
import numpy as np

# %%
df_novo = pd.read_csv('meu_arquivo.csv.zip', compression='zip')

# %%
df_novo
# Out:
#                    lens_id jurisdiction    doc_number kind date_published  \
# 0      003-669-596-743-255           BR  112020025554   A2     2021-09-28
# 1      004-472-192-770-297           BR     MU9000507   U2     2011-12-20
# 2      007-500-074-980-888           BR       8301793    U     2004-04-20
# 3      004-893-813-349-290           BR  102020025256   B1     2021-12-14
# 4      000-298-646-671-474           BR  112022026579   A2     2023-01-17
# ...                    ...          ...           ...  ...            ...
# 25235  060-177-888-098-32X           BR  112013021969   B1     2020-12-15
# 25236  063-771-835-140-759           BR  202017016843   U2     2019-03-19
# 25237  060-787-914-515-157           BR  202022009927   U2     2022-11-29
# 25238  061-351-019-154-104           BR       7802603    U     2000-06-27
# 25239  061-547-058-005-157           BR  112014004470   B1     2021-02-23
#
#                            doc_key   docdb_id lang  \
# ...
